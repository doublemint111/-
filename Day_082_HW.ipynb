# %%
import os
import tensorflow.keras

# 本範例不需使用 GPU, 將 GPU 設定為 "無"
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = tensorflow.keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = tensorflow.keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from tensorflow.keras.layers import Dropout

"""
建立神經網路，並加入 dropout layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = tensorflow.keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = tensorflow.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = tensorflow.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = tensorflow.keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = tensorflow.keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
Dropout_EXP = 0.25

# %%
model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP)
model.summary()
optimizer = tensorflow.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 45us/sample - loss: 2.1838 - accuracy: 0.1848 - val_loss: 1.9892 - val_accuracy: 0.2919
# Epoch 2/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.9999 - accuracy: 0.2664 - val_loss: 1.8745 - val_accuracy: 0.3339
# Epoch 3/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.9199 - accuracy: 0.3023 - val_loss: 1.8077 - val_accuracy: 0.3639
# Epoch 4/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.8662 - accuracy: 0.3268 - val_loss: 1.7568 - val_accuracy: 0.3820
# Epoch 5/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.8207 - accuracy: 0.3447 - val_loss: 1.7153 - val_accuracy: 0.3943
# Epoch 6/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.7866 - accuracy: 0.3572 - val_loss: 1.6834 - val_accuracy: 0.4124
# Epoch 7/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.7569 - accuracy: 0.3701 - val_loss: 1.6532 - val_accuracy: 0.4195
# Epoch 8/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.7313 - accuracy: 0.3801 - val_loss: 1.6272 - val_accuracy: 0.4306
# Epoch 9/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.7080 - accuracy: 0.3890 - val_loss: 1.6081 - val_accuracy: 0.4344
# Epoch 10/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.6856 - accuracy: 0.3981 - val_loss: 1.5876 - val_accuracy: 0.4384
# Epoch 11/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.6692 - accuracy: 0.4059 - val_loss: 1.5708 - val_accuracy: 0.4458
# Epoch 12/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.6507 - accuracy: 0.4109 - val_loss: 1.5514 - val_accuracy: 0.4497
# Epoch 13/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.6295 - accuracy: 0.4228 - val_loss: 1.5436 - val_accuracy: 0.4576
# Epoch 14/50
# 50000/50000 [==============================] - 2s 34us/sample - loss: 1.6141 - accuracy: 0.4259 - val_loss: 1.5201 - val_accuracy: 0.4639
# Epoch 15/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.5971 - accuracy: 0.4323 - val_loss: 1.5137 - val_accuracy: 0.4654
# Epoch 16/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.5834 - accuracy: 0.4376 - val_loss: 1.4958 - val_accuracy: 0.4737
# Epoch 17/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.5723 - accuracy: 0.4402 - val_loss: 1.4905 - val_accuracy: 0.4777
# Epoch 18/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.5599 - accuracy: 0.4443 - val_loss: 1.4795 - val_accuracy: 0.4757
# Epoch 19/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.5452 - accuracy: 0.4505 - val_loss: 1.4666 - val_accuracy: 0.4819
# Epoch 20/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.5384 - accuracy: 0.4508 - val_loss: 1.4560 - val_accuracy: 0.4849
# Epoch 21/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.5215 - accuracy: 0.4596 - val_loss: 1.4440 - val_accuracy: 0.4919
# Epoch 22/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.5115 - accuracy: 0.4625 - val_loss: 1.4391 - val_accuracy: 0.4906
# Epoch 23/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.5004 - accuracy: 0.4657 - val_loss: 1.4386 - val_accuracy: 0.4850
# Epoch 24/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4948 - accuracy: 0.4682 - val_loss: 1.4318 - val_accuracy: 0.4902
# Epoch 25/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.4826 - accuracy: 0.4710 - val_loss: 1.4243 - val_accuracy: 0.4940
# Epoch 26/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4715 - accuracy: 0.4772 - val_loss: 1.4126 - val_accuracy: 0.4960
# Epoch 27/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.4652 - accuracy: 0.4777 - val_loss: 1.4077 - val_accuracy: 0.4969
# Epoch 28/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.4564 - accuracy: 0.4821 - val_loss: 1.3931 - val_accuracy: 0.5046
# Epoch 29/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4414 - accuracy: 0.4879 - val_loss: 1.3906 - val_accuracy: 0.5066
# Epoch 30/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4339 - accuracy: 0.4876 - val_loss: 1.3975 - val_accuracy: 0.5037
# Epoch 31/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4296 - accuracy: 0.4913 - val_loss: 1.3808 - val_accuracy: 0.5107
# Epoch 32/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.4198 - accuracy: 0.4954 - val_loss: 1.3800 - val_accuracy: 0.5059
# Epoch 33/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.4051 - accuracy: 0.5000 - val_loss: 1.3786 - val_accuracy: 0.5074
# Epoch 34/50
# 50000/50000 [==============================] - 2s 33us/sample - loss: 1.4031 - accuracy: 0.4999 - val_loss: 1.3621 - val_accuracy: 0.5117
# Epoch 35/50
# 50000/50000 [==============================] - 2s 35us/sample - loss: 1.3957 - accuracy: 0.5028 - val_loss: 1.3667 - val_accuracy: 0.5118
# Epoch 36/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3834 - accuracy: 0.5069 - val_loss: 1.3548 - val_accuracy: 0.5150
# Epoch 37/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3825 - accuracy: 0.5068 - val_loss: 1.3573 - val_accuracy: 0.5164
# Epoch 38/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3736 - accuracy: 0.5099 - val_loss: 1.3587 - val_accuracy: 0.5124
# Epoch 39/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3641 - accuracy: 0.5146 - val_loss: 1.3478 - val_accuracy: 0.5166
# Epoch 40/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.3551 - accuracy: 0.5172 - val_loss: 1.3511 - val_accuracy: 0.5198
# Epoch 41/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3523 - accuracy: 0.5183 - val_loss: 1.3393 - val_accuracy: 0.5189
# Epoch 42/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.3419 - accuracy: 0.5216 - val_loss: 1.3388 - val_accuracy: 0.5194
# Epoch 43/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3373 - accuracy: 0.5250 - val_loss: 1.3305 - val_accuracy: 0.5275
# Epoch 44/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3347 - accuracy: 0.5236 - val_loss: 1.3332 - val_accuracy: 0.5217
# Epoch 45/50
# 50000/50000 [==============================] - 2s 30us/sample - loss: 1.3213 - accuracy: 0.5318 - val_loss: 1.3318 - val_accuracy: 0.5217
# Epoch 46/50
# 50000/50000 [==============================] - 2s 30us/sample - loss: 1.3181 - accuracy: 0.5303 - val_loss: 1.3341 - val_accuracy: 0.5271
# Epoch 47/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3102 - accuracy: 0.5327 - val_loss: 1.3177 - val_accuracy: 0.5241
# Epoch 48/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3027 - accuracy: 0.5374 - val_loss: 1.3191 - val_accuracy: 0.5310
# Epoch 49/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.3015 - accuracy: 0.5349 - val_loss: 1.3185 - val_accuracy: 0.5268
# Epoch 50/50
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.2933 - accuracy: 0.5381 - val_loss: 1.3184 - val_accuracy: 0.5252

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %% [markdown]
# ## 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# ## 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import itertools

# %%
# 從 Keras 的內建功能中，取得 train 與 test 資料集
train, test = tensorflow.keras.datasets.cifar10.load_data()

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
## 超參數設定
LEARNING_RATE = 1e-4
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95

"""
建立實驗組合
"""
Dropout_EXP = [0.1, 0.2, 0.4]
LAYER_NEURONS = [[128, 128, 128], [128, 256, 256], [128, 256, 512]]

# %%
results = {}
"""
以迴圈方式遍歷組合來訓練模型
"""
for i, (layer_neurons, drp_rate) in enumerate(itertools.product(LAYER_NEURONS, Dropout_EXP)):
    print("Numbers of exp: %i, layer: %s, dropout_rate: %.2f" % (i, layer_neurons, drp_rate))
    model = build_mlp(input_shape=x_train.shape[1:], num_neurons=layer_neurons, drp_ratio=drp_rate)
    model.summary()
    optimizer = tensorflow.keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              verbose=0,
              shuffle=True)

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-accuracy': model.history.history["accuracy"],
                             'valid-accuracy': model.history.history["val_accuracy"]}
# Out:
# Numbers of exp: 0, layer: [128, 128, 128], dropout_rate: 0.10
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 427,658
# Trainable params: 427,658
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 1, layer: [128, 128, 128], dropout_rate: 0.20
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 427,658
# Trainable params: 427,658
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 2, layer: [128, 128, 128], dropout_rate: 0.40
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 427,658
# Trainable params: 427,658
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 3, layer: [128, 256, 256], dropout_rate: 0.10
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 494,730
# Trainable params: 494,730
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 4, layer: [128, 256, 256], dropout_rate: 0.20
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 494,730
# Trainable params: 494,730
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 5, layer: [128, 256, 256], dropout_rate: 0.40
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 494,730
# Trainable params: 494,730
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 6, layer: [128, 256, 512], dropout_rate: 0.10
# Model: "model_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 512)               131584
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                5130
# =================================================================
# Total params: 563,082
# Trainable params: 563,082
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 7, layer: [128, 256, 512], dropout_rate: 0.20
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 512)               131584
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                5130
# =================================================================
# Total params: 563,082
# Trainable params: 563,082
# Non-trainable params: 0
# _________________________________________________________________
# Numbers of exp: 8, layer: [128, 256, 512], dropout_rate: 0.40
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               33024
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 512)               131584
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 512)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                5130
# =================================================================
# Total params: 563,082
# Trainable params: 563,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

# %%
plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-accuracy'])),results[cond]['train-accuracy'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-accuracy'])),results[cond]['valid-accuracy'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
