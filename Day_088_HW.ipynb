# %%
import os
import tensorflow.keras
import itertools
import numpy as np
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""

# %%
train, test = tensorflow.keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = tensorflow.keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from tensorflow.keras.layers import BatchNormalization
def build_mlp(input_shape, output_units=10, num_neurons=[256, 256, 256]):
    input_layer = tensorflow.keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = tensorflow.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = tensorflow.keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = tensorflow.keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = tensorflow.keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from tensorflow.keras.callbacks import Callback

class f1sc(tensorflow.keras.callbacks.Callback):
    
    def __init__(self, val_data=(x_test, y_test)):
        self.validation_data = val_data
    
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
            except:
                self.params['metrics']=i
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = tensorflow.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 44us/sample - loss: 2.2533 - accuracy: 0.2601 - val_loss: 2.1663 - val_accuracy: 0.1827 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.7627 - accuracy: 0.3832 - val_loss: 1.9793 - val_accuracy: 0.2821 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.6371 - accuracy: 0.4229 - val_loss: 1.8123 - val_accuracy: 0.3678 - val_tp: 24.0000 - val_tn: 1000.0000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.5635 - accuracy: 0.4503 - val_loss: 1.7012 - val_accuracy: 0.4039 - val_tp: 174.0000 - val_tn: 1000.0000
# Epoch 5/50
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.5114 - accuracy: 0.4702 - val_loss: 1.6255 - val_accuracy: 0.4250 - val_tp: 369.0000 - val_tn: 1000.0000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.4670 - accuracy: 0.4856 - val_loss: 1.5820 - val_accuracy: 0.4410 - val_tp: 894.0000 - val_tn: 995.0000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.4301 - accuracy: 0.4978 - val_loss: 1.5443 - val_accuracy: 0.4513 - val_tp: 1714.0000 - val_tn: 983.0000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.3985 - accuracy: 0.5083 - val_loss: 1.5172 - val_accuracy: 0.4644 - val_tp: 1362.0000 - val_tn: 987.0000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.3675 - accuracy: 0.5204 - val_loss: 1.5174 - val_accuracy: 0.4649 - val_tp: 1626.0000 - val_tn: 981.0000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.3404 - accuracy: 0.5311 - val_loss: 1.4999 - val_accuracy: 0.4680 - val_tp: 1871.0000 - val_tn: 979.0000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.3145 - accuracy: 0.5395 - val_loss: 1.4878 - val_accuracy: 0.4737 - val_tp: 2311.0000 - val_tn: 984.0000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.2913 - accuracy: 0.5484 - val_loss: 1.4720 - val_accuracy: 0.4818 - val_tp: 1877.0000 - val_tn: 979.0000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.2697 - accuracy: 0.5579 - val_loss: 1.4779 - val_accuracy: 0.4772 - val_tp: 2389.0000 - val_tn: 979.0000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.2473 - accuracy: 0.5648 - val_loss: 1.4794 - val_accuracy: 0.4781 - val_tp: 2097.0000 - val_tn: 981.0000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.2270 - accuracy: 0.5723 - val_loss: 1.4595 - val_accuracy: 0.4841 - val_tp: 2240.0000 - val_tn: 982.0000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.2060 - accuracy: 0.5798 - val_loss: 1.4613 - val_accuracy: 0.4902 - val_tp: 2711.0000 - val_tn: 975.0000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.1863 - accuracy: 0.5869 - val_loss: 1.4582 - val_accuracy: 0.4866 - val_tp: 1502.0000 - val_tn: 986.0000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.1681 - accuracy: 0.5943 - val_loss: 1.4582 - val_accuracy: 0.4887 - val_tp: 2026.0000 - val_tn: 981.0000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.1498 - accuracy: 0.6012 - val_loss: 1.4574 - val_accuracy: 0.4878 - val_tp: 1708.0000 - val_tn: 982.0000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1311 - accuracy: 0.6092 - val_loss: 1.4507 - val_accuracy: 0.4911 - val_tp: 1912.0000 - val_tn: 975.0000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1147 - accuracy: 0.6154 - val_loss: 1.4584 - val_accuracy: 0.4892 - val_tp: 1485.0000 - val_tn: 987.0000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0963 - accuracy: 0.6223 - val_loss: 1.4452 - val_accuracy: 0.4953 - val_tp: 2046.0000 - val_tn: 974.0000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.0808 - accuracy: 0.6275 - val_loss: 1.4591 - val_accuracy: 0.4895 - val_tp: 1723.0000 - val_tn: 984.0000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0635 - accuracy: 0.6340 - val_loss: 1.4583 - val_accuracy: 0.4887 - val_tp: 1758.0000 - val_tn: 984.0000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0467 - accuracy: 0.6418 - val_loss: 1.4489 - val_accuracy: 0.4955 - val_tp: 1732.0000 - val_tn: 983.0000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0311 - accuracy: 0.6468 - val_loss: 1.4586 - val_accuracy: 0.4926 - val_tp: 2011.0000 - val_tn: 977.0000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0138 - accuracy: 0.6543 - val_loss: 1.4593 - val_accuracy: 0.4939 - val_tp: 1623.0000 - val_tn: 985.0000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9984 - accuracy: 0.6603 - val_loss: 1.4615 - val_accuracy: 0.5006 - val_tp: 1903.0000 - val_tn: 981.0000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.9824 - accuracy: 0.6657 - val_loss: 1.4760 - val_accuracy: 0.4906 - val_tp: 2429.0000 - val_tn: 973.0000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9675 - accuracy: 0.6694 - val_loss: 1.4697 - val_accuracy: 0.4968 - val_tp: 1994.0000 - val_tn: 980.0000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9529 - accuracy: 0.6772 - val_loss: 1.4658 - val_accuracy: 0.4960 - val_tp: 2102.0000 - val_tn: 981.0000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9355 - accuracy: 0.6852 - val_loss: 1.4793 - val_accuracy: 0.4940 - val_tp: 2031.0000 - val_tn: 978.0000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9209 - accuracy: 0.6891 - val_loss: 1.4768 - val_accuracy: 0.5028 - val_tp: 1944.0000 - val_tn: 982.0000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.9081 - accuracy: 0.6934 - val_loss: 1.4836 - val_accuracy: 0.4942 - val_tp: 2644.0000 - val_tn: 968.0000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.8914 - accuracy: 0.7000 - val_loss: 1.4943 - val_accuracy: 0.4907 - val_tp: 1556.0000 - val_tn: 986.0000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.8779 - accuracy: 0.7068 - val_loss: 1.4969 - val_accuracy: 0.4963 - val_tp: 2321.0000 - val_tn: 971.0000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.8617 - accuracy: 0.7145 - val_loss: 1.4968 - val_accuracy: 0.4967 - val_tp: 1992.0000 - val_tn: 983.0000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.8472 - accuracy: 0.7177 - val_loss: 1.4935 - val_accuracy: 0.4979 - val_tp: 2795.0000 - val_tn: 972.0000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.8315 - accuracy: 0.7247 - val_loss: 1.5069 - val_accuracy: 0.4944 - val_tp: 2588.0000 - val_tn: 970.0000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.8193 - accuracy: 0.7301 - val_loss: 1.5309 - val_accuracy: 0.4884 - val_tp: 2475.0000 - val_tn: 967.0000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.8056 - accuracy: 0.7349 - val_loss: 1.5231 - val_accuracy: 0.4942 - val_tp: 2811.0000 - val_tn: 969.0000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.7897 - accuracy: 0.7407 - val_loss: 1.5194 - val_accuracy: 0.4943 - val_tp: 2428.0000 - val_tn: 973.0000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.7752 - accuracy: 0.7470 - val_loss: 1.5350 - val_accuracy: 0.4956 - val_tp: 1930.0000 - val_tn: 984.0000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.7617 - accuracy: 0.7518 - val_loss: 1.5562 - val_accuracy: 0.4914 - val_tp: 3086.0000 - val_tn: 955.0000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 29us/sample - loss: 0.7472 - accuracy: 0.7570 - val_loss: 1.5468 - val_accuracy: 0.4953 - val_tp: 2310.0000 - val_tn: 970.0000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.7339 - accuracy: 0.7640 - val_loss: 1.5453 - val_accuracy: 0.4959 - val_tp: 2645.0000 - val_tn: 967.0000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.7197 - accuracy: 0.7704 - val_loss: 1.5567 - val_accuracy: 0.4909 - val_tp: 1951.0000 - val_tn: 983.0000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.7047 - accuracy: 0.7753 - val_loss: 1.5699 - val_accuracy: 0.4956 - val_tp: 2694.0000 - val_tn: 964.0000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 28us/sample - loss: 0.6930 - accuracy: 0.7792 - val_loss: 1.5828 - val_accuracy: 0.4901 - val_tp: 2558.0000 - val_tn: 969.0000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 27us/sample - loss: 0.6790 - accuracy: 0.7841 - val_loss: 1.5852 - val_accuracy: 0.4932 - val_tp: 2521.0000 - val_tn: 973.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()

# %% [markdown]
# ## Work
#
# 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
class f1sc(tensorflow.keras.callbacks.Callback):
    
    def __init__(self, val_data=(x_test, y_test)):
        self.validation_data = val_data
    
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
            except:
                self.params['metrics']=i
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = tensorflow.keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn]
         )

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_24 (InputLayer)        [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 256)               786688
# _________________________________________________________________
# batch_normalization_69 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_70 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 256)               65792
# _________________________________________________________________
# batch_normalization_71 (Batc (None, 256)               1024
# _________________________________________________________________
# output (Dense)               (None, 10)                2570
# =================================================================
# Total params: 923,914
# Trainable params: 922,378
# Non-trainable params: 1,536
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 42us/sample - loss: 2.2491 - accuracy: 0.2637 - val_loss: 2.1371 - val_accuracy: 0.2107 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 2/25
# 50000/50000 [==============================] - 2s 31us/sample - loss: 1.7709 - accuracy: 0.3824 - val_loss: 1.9866 - val_accuracy: 0.2922 - val_tp: 0.0000e+00 - val_tn: 1000.0000
# Epoch 3/25
# 50000/50000 [==============================] - 2s 32us/sample - loss: 1.6430 - accuracy: 0.4241 - val_loss: 1.8149 - val_accuracy: 0.3677 - val_tp: 3.0000 - val_tn: 1000.0000
# Epoch 4/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.5700 - accuracy: 0.4521 - val_loss: 1.7138 - val_accuracy: 0.4027 - val_tp: 99.0000 - val_tn: 1000.0000
# Epoch 5/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.5152 - accuracy: 0.4692 - val_loss: 1.6288 - val_accuracy: 0.4290 - val_tp: 471.0000 - val_tn: 999.0000
# Epoch 6/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.4709 - accuracy: 0.4848 - val_loss: 1.5789 - val_accuracy: 0.4432 - val_tp: 648.0000 - val_tn: 996.0000
# Epoch 7/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.4331 - accuracy: 0.4981 - val_loss: 1.5475 - val_accuracy: 0.4544 - val_tp: 1047.0000 - val_tn: 993.0000
# Epoch 8/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.3986 - accuracy: 0.5110 - val_loss: 1.5234 - val_accuracy: 0.4636 - val_tp: 980.0000 - val_tn: 993.0000
# Epoch 9/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.3696 - accuracy: 0.5225 - val_loss: 1.5138 - val_accuracy: 0.4689 - val_tp: 1017.0000 - val_tn: 991.0000
# Epoch 10/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.3418 - accuracy: 0.5323 - val_loss: 1.5056 - val_accuracy: 0.4676 - val_tp: 1382.0000 - val_tn: 987.0000
# Epoch 11/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.3157 - accuracy: 0.5416 - val_loss: 1.4855 - val_accuracy: 0.4810 - val_tp: 2151.0000 - val_tn: 983.0000
# Epoch 12/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.2909 - accuracy: 0.5502 - val_loss: 1.4783 - val_accuracy: 0.4801 - val_tp: 1191.0000 - val_tn: 990.0000
# Epoch 13/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.2678 - accuracy: 0.5588 - val_loss: 1.4652 - val_accuracy: 0.4857 - val_tp: 1622.0000 - val_tn: 985.0000
# Epoch 14/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.2453 - accuracy: 0.5680 - val_loss: 1.4569 - val_accuracy: 0.4857 - val_tp: 1799.0000 - val_tn: 984.0000
# Epoch 15/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.2230 - accuracy: 0.5772 - val_loss: 1.4747 - val_accuracy: 0.4859 - val_tp: 1659.0000 - val_tn: 986.0000
# Epoch 16/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.2024 - accuracy: 0.5855 - val_loss: 1.4483 - val_accuracy: 0.4930 - val_tp: 1708.0000 - val_tn: 988.0000
# Epoch 17/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1850 - accuracy: 0.5906 - val_loss: 1.4505 - val_accuracy: 0.4891 - val_tp: 1639.0000 - val_tn: 988.0000
# Epoch 18/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1657 - accuracy: 0.5974 - val_loss: 1.4542 - val_accuracy: 0.4881 - val_tp: 1435.0000 - val_tn: 987.0000
# Epoch 19/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.1441 - accuracy: 0.6061 - val_loss: 1.4424 - val_accuracy: 0.4965 - val_tp: 2339.0000 - val_tn: 977.0000
# Epoch 20/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1268 - accuracy: 0.6127 - val_loss: 1.4489 - val_accuracy: 0.4947 - val_tp: 1378.0000 - val_tn: 989.0000
# Epoch 21/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.1092 - accuracy: 0.6192 - val_loss: 1.4451 - val_accuracy: 0.4975 - val_tp: 2259.0000 - val_tn: 982.0000
# Epoch 22/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.0919 - accuracy: 0.6252 - val_loss: 1.4433 - val_accuracy: 0.4954 - val_tp: 1695.0000 - val_tn: 987.0000
# Epoch 23/25
# 50000/50000 [==============================] - 1s 29us/sample - loss: 1.0727 - accuracy: 0.6343 - val_loss: 1.4358 - val_accuracy: 0.5025 - val_tp: 1853.0000 - val_tn: 982.0000
# Epoch 24/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0575 - accuracy: 0.6381 - val_loss: 1.4607 - val_accuracy: 0.4918 - val_tp: 1715.0000 - val_tn: 987.0000
# Epoch 25/25
# 50000/50000 [==============================] - 1s 28us/sample - loss: 1.0413 - accuracy: 0.6442 - val_loss: 1.4438 - val_accuracy: 0.4991 - val_tp: 2367.0000 - val_tn: 976.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
